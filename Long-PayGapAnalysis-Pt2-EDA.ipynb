# %%
import pandas as pd
import matplotlib 
import matplotlib.pyplot as plt
from matplotlib import style
import numpy as np


data = pd.read_csv("Glassdoor_Gender_Pay_Gap.csv")

# %%
data.head()
# Out:
#               JobTitle  Gender  Age  PerfEval Education            Dept  \
# 0     Graphic Designer  Female   18         5   College      Operations
# 1    Software Engineer    Male   21         5   College      Management
# 2  Warehouse Associate  Female   19         4       PhD  Administration
# 3    Software Engineer    Male   20         5   Masters           Sales
# 4     Graphic Designer    Male   26         5   Masters     Engineering
#
#    Seniority  BasePay  Bonus
# 0          2    42363   9938
# 1          5   108476  11128
# 2          5    90208   9268
# 3          4   108080  10154
# 4          5    99464   9319

# %%
data.shape
# Out:
# (1000, 9)

# %%
unique_job_titles = data['JobTitle'].nunique()
unique_job_titles
# Out:
# 10

# %%
data["JobTitle"].value_counts()
# Out:
# Marketing Associate    118
# Software Engineer      109
# Financial Analyst      107
# Data Scientist         107
# Graphic Designer        98
# IT                      96
# Sales Associate         94
# Driver                  91
# Warehouse Associate     90
# Manager                 90
# Name: JobTitle, dtype: int64

# %%
data["Gender"].value_counts()
# Out:
# Male      532
# Female    468
# Name: Gender, dtype: int64

# %%
data["PerfEval"].value_counts()
# Out:
# 5    209
# 4    207
# 1    198
# 3    194
# 2    192
# Name: PerfEval, dtype: int64

# %%
data["Seniority"].value_counts()
# Out:
# 3    219
# 2    209
# 1    195
# 5    193
# 4    184
# Name: Seniority, dtype: int64

# %%
data["Dept"].value_counts()
# Out:
# Operations        210
# Sales             207
# Management        198
# Administration    193
# Engineering       192
# Name: Dept, dtype: int64

# %%
data["Education"].value_counts()
# Out:
# High School    265
# Masters        256
# College        241
# PhD            238
# Name: Education, dtype: int64

# %%
for col in data.columns:
    pct_missing = np.mean(data[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100,9)))
    
#no data is missing
# Out:
# JobTitle - 0.0%
# Gender - 0.0%
# Age - 0.0%
# PerfEval - 0.0%
# Education - 0.0%
# Dept - 0.0%
# Seniority - 0.0%
# BasePay - 0.0%
# Bonus - 0.0%

# %%
data["BasePay"].describe()
# Out:
# count      1000.000000
# mean      94472.653000
# std       25337.493272
# min       34208.000000
# 25%       76850.250000
# 50%       93327.500000
# 75%      111558.000000
# max      179726.000000
# Name: BasePay, dtype: float64

# %%
data["Bonus"].describe()
# Out:
# count     1000.000000
# mean      6467.161000
# std       2004.377365
# min       1703.000000
# 25%       4849.500000
# 50%       6507.000000
# 75%       8026.000000
# max      11293.000000
# Name: Bonus, dtype: float64

# %%
data["Age"].describe()
# Out:
# count    1000.000000
# mean       41.393000
# std        14.294856
# min        18.000000
# 25%        29.000000
# 50%        41.000000
# 75%        54.250000
# max        65.000000
# Name: Age, dtype: float64

# %%
data.hist('BasePay')
plt.show()

# %%
Summarize Your Results
With your EDA complete, answer the following questions.

Was there anything surprising about your dataset?
Do you have any concerns about your dataset?
Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?

# %%
data.hist('Bonus')
plt.show()

# %%
data.hist('Age')
plt.show()

# %%
data.plot.box("Gender")
# plot.show()
# Out:
# Age             Axes(0.125,0.11;0.133621x0.77)
# BasePay      Axes(0.285345,0.11;0.133621x0.77)
# Bonus         Axes(0.44569,0.11;0.133621x0.77)
# PerfEval     Axes(0.606034,0.11;0.133621x0.77)
# Seniority    Axes(0.766379,0.11;0.133621x0.77)
# dtype: object

# %%
data.plot.box('Gender')
plt.show()

# %%
data['Gender'].value_counts().plot(kind='bar');

# %%
data['JobTitle'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ## Summarize Your Results
# With your EDA complete, answer the following questions.
#
# 1. Was there anything surprising about your dataset?
# I was surprised that there were not any null data points.
# 2. Do you have any concerns about your dataset?
# Slight concern with the data not being 50% male to female, but it is relatively close
# 3. Is there anything you want to make note of for the next phase of your analysis, which is cleaning data?
# Find out more information around the PerfEval data points. Explore seniority a bit more as well. There are not any missing values. Check for outliers and duplicates, mostly duplicates. By looking at these charts, the data seems pretty symmetrical without outliers. Maybe rename columns to lowercase if that will be easier.
